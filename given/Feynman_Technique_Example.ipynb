# %%
from google import genai
import os
from typing import Dict, List

# select your model
model = "gemini-2.5-flash"
client = genai.Client(api_key="AIzaSyD9dJOSk9M4CgjzyeBjsYvDk4ySoIULPJk")

# %%
# Test setup
response = client.models.generate_content(
    model= model,
    contents="Hello!"
)
print(response.text)
print("✓ Setup complete!")
# Out:
# Hello! How can I help you today?
# ✓ Setup complete!

# %%
from prompt_template import PromptTemplate, FeynmanTemplate

# %% [markdown]
# # Example Prompt

# %%
print("\n" + "=" * 70)
print("EXAMPLE 1: Basic Task Only")
print("=" * 70)

# Create a simple template
prompt = PromptTemplate("Explain Quantum Computing")

print("\n[Constructed Prompt]")
print(prompt.full_prompt())
# Out:
# ======================================================================
# EXAMPLE 1: Basic Task Only
# ======================================================================
#
# [Constructed Prompt]
# Explain Quantum Computing

# %%
print("\n[Response]")
response = prompt.generate(client, model)
print(response)
# Out:
# [Response]
# Quantum computing is a revolutionary new type of computing that leverages the principles of quantum mechanics to solve problems that are intractable for even the most powerful classical supercomputers.
#
# To understand it, let's break it down by contrasting it with classical computing:
#
# ---
#
# ### Classical Computing vs. Quantum Computing
#
# **1. The Basic Unit of Information:**
#
# *   **Classical Computers:** Use **bits**. A bit can be either a **0 or a 1** at any given time.
#     *   *Analogy:* Like a light switch that is either ON or OFF.
# *   **Quantum Computers:** Use **qubits**. A qubit can be a **0, a 1, or both at the same time** (due to superposition).
#     *   *Analogy:* Like a spinning coin that is heads, tails, or somewhere in between until it lands.
#
# ---
#
# ### Key Principles of Quantum Computing
#
# The power of quantum computing comes from three fundamental phenomena of quantum mechanics:
#
# 1.  **Superposition:**
#     *   A qubit can exist in a combination of multiple states simultaneously. This means it can be 0 and 1 at the same time, each with a certain probability.
#     *   **Why it's powerful:** If you have multiple qubits in superposition, the number of states they can represent simultaneously grows exponentially. For example, two bits can be in one of four states (00, 01, 10, 11) at a time. Two *qubits* can represent *all four* of those states *at the same time*. This allows quantum computers to process many possibilities simultaneously, rather than sequentially.
#
# 2.  **Entanglement:**
#     *   When two or more qubits become entangled, they become interconnected in such a way that the state of one instantly influences the state of the others, regardless of the distance between them. It's often described as "spooky action at a distance."
#     *   **Why it's powerful:** Entanglement allows qubits to perform incredibly complex correlations and calculations. It creates a vast, interconnected computational space that far exceeds what independent qubits could achieve. If you know the state of one entangled qubit, you instantly know something about the state of its entangled partner(s).
#
# 3.  **Interference:**
#     *   Quantum computers harness the phenomenon of wave interference. Just like waves of water can add up (constructive interference) or cancel each other out (destructive interference), quantum probabilities can interfere.
#     *   **Why it's powerful:** Quantum algorithms are designed to amplify the probabilities of correct answers and diminish the probabilities of incorrect answers, allowing the computer to "find" the right solution among countless possibilities when measured.
#
# ---
#
# ### How a Quantum Computer Works (Conceptually)
#
# 1.  **Initialization:** Qubits are prepared in a known initial state, often a superposition.
# 2.  **Quantum Gates:** Operations called "quantum gates" are applied to the qubits. These are the quantum equivalent of classical logic gates (AND, OR, NOT) but can manipulate qubits while they are in superposition and entanglement. This is where the actual computation happens, exploring many potential solutions simultaneously.
# 3.  **Measurement:** Finally, the qubits are measured. This collapses their superposition into a definite classical state (0 or 1). Because of the probabilistic nature, the result isn't always the same, but clever algorithms ensure that the correct answer has a much higher probability of being measured.
#
# ---
#
# ### What Makes it Powerful?
#
# Quantum computers aren't just "faster" classical computers; they are fundamentally different. They excel at problems that involve:
#
# *   **Simulating complex systems:** Modeling molecules for drug discovery, materials science, or chemical reactions.
# *   **Factoring large numbers:** Breaking modern encryption methods (like RSA) with Shor's algorithm.
# *   **Optimization problems:** Finding the most efficient routes, financial models, or logistics.
# *   **Machine Learning:** Enhancing AI algorithms (quantum machine learning).
# *   **Database Search:** Speeding up unstructured database searches with Grover's algorithm.
#
# ---
#
# ### What Quantum Computing is NOT
#
# *   **A replacement for classical computers:** You won't be browsing the internet or writing emails on a quantum computer. They are specialized tools for specific, hard problems.
# *   **Faster at everything:** They are not designed to be faster at tasks classical computers already do well.
# *   **Always giving a single, deterministic answer:** Due to the probabilistic nature of measurement, quantum algorithms often need to be run multiple times to confirm results.
#
# ---
#
# ### Current Status and Challenges
#
# Quantum computing is still in its early stages ("Noisy Intermediate-Scale Quantum" or NISQ era).
#
# *   **Challenges:**
#     *   **Decoherence:** Qubits are extremely fragile and lose their quantum properties very easily due to interaction with their environment (heat, vibration, electromagnetic fields). This is why they often need to be kept at near absolute zero temperatures in special dilution refrigerators.
#     *   **Error Correction:** It's incredibly difficult to correct errors in qubits without disturbing their quantum state.
#     *   **Scalability:** Building quantum computers with a large number of stable, high-quality qubits is a huge engineering challenge.
#     *   **Algorithm Development:** Developing effective quantum algorithms is an active area of research.
#
# Despite the challenges, significant progress is being made by companies like IBM, Google, Microsoft, and many startups. While we don't have a "fault-tolerant" universal quantum computer yet, the field is rapidly advancing, promising to unlock solutions to some of humanity's most complex problems in the future.

# %% [markdown]
# # Feynman Approach

# %%
prompt = FeynmanTemplate("Explain Quantum Computing")
prompt = prompt.with_feynman_learning("a high school student", num_rounds=2)
prompt = prompt.with_knowledge_gap_focus(specific_gaps=["quantum probability"])
prompt = prompt.with_chain_of_thought()

print("\n[Constructed Prompt]")
print(prompt.full_prompt())
# Out:
# [Constructed Prompt]
# Explain Quantum Computing
#
# Apply the Feynman Learning Technique:
#
# Step 1 - Simple Explanation:
# Explain this concept as if teaching a high school student. Use simple language, avoid jargon.
#
# Step 2 - Identify Gaps:
# Where did you struggle to explain it simply? What parts were unclear?
#
# Step 3 - Refine Your Explanation:
# Address the gaps you identified. Improve clarity and simplicity.
#
# Step 4 - Iterate and Refine:
# Repeat steps 2-3 for 2 refinement round(s) to deepen understanding.
#
# Pay special attention to these knowledge gaps:
#   - quantum probability
#
# For each gap, provide a clear, simple explanation that a beginner could understand.
#
# Think through this step-by-step and show your reasoning.

# %%
print("\n[Response]")
response = prompt.generate(client, model)
print(response)
# Out:
# [Response]
# Okay, let's break down Quantum Computing using the Feynman Learning Technique.
#
# ---
#
# ### Step 1 - Simple Explanation
#
# Imagine your regular computer, like the laptop or phone you're using. It works with "bits," which are like light switches that can be either **ON** (representing a 1) or **OFF** (representing a 0). Every piece of information, every calculation, is done by flicking millions of these tiny switches.
#
# Now, imagine a *quantum* computer. Instead of simple on/off switches, it uses "qubits." Think of a qubit not just as a light switch, but as a **dimmer switch**.
#
# 1.  **Superposition (The Dimmer Switch):** A dimmer switch can be ON, OFF, or **anywhere in between** – half-on, a quarter-on, etc. A qubit is similar: it can be 0, 1, or both 0 and 1 at the same time, to varying degrees. This "being in multiple states at once" is called **superposition**. It's like the qubit is exploring all possibilities simultaneously. When you finally "look" at the dimmer, it has to settle on either fully ON or fully OFF, but before you look, it's fuzzy.
#
# 2.  **Entanglement (Linked Dimmer Switches):** Imagine two dimmer switches that are mysteriously linked. If you change one, the other instantly changes in a related way, no matter how far apart they are. In a quantum computer, qubits can become "entangled." This means their fates are tied together. Measuring the state of one instantly tells you something about the state of the other, even if they're not physically close. This allows qubits to work together in very complex ways.
#
# 3.  **Quantum Computers "Solve":** Because qubits can be in superposition and be entangled, a quantum computer can explore many, many solutions to a problem *all at once*. A regular computer would have to try each solution one by one. This makes quantum computers incredibly powerful for very specific kinds of problems that are too complex for even the best supercomputers, like designing new materials, breaking tough encryption, or finding optimal solutions in vast datasets.
#
# **In short:** Quantum computers use "qubits" that can exist in multiple states at once (superposition) and be linked together (entanglement). This allows them to process vast amounts of information simultaneously, solving certain problems much faster than any traditional computer. They aren't just super-fast regular computers for everything; they are a completely new type of computer for specific, very hard challenges.
#
# ---
#
# ### Step 2 - Identify Gaps
#
# Here's where I felt I simplified too much or struggled to make things perfectly clear for a high school student:
#
# 1.  **"Anywhere in between" / "Both 0 and 1 at the same time":** While the dimmer switch analogy is good, explaining *how* something can be "both 0 and 1 at the same time" is conceptually difficult. It's not like it's literally 0 AND 1, but rather a *potential* for either, weighted in a certain way. This ties directly into quantum probability.
# 2.  **Quantum Probability:** I mentioned "When you finally 'look' at the dimmer, it has to settle on either fully ON or fully OFF, but before you look, it's fuzzy." This is an attempt, but it doesn't clearly explain *how* that "settling" happens or *why* it settles on one state over another. The idea of probability in the quantum world is very different from classical probability, and I didn't address that distinction at all. How does the "fuzziness" determine the final outcome?
# 3.  **"Mysteriously linked" / "Fates are tied":** Entanglement is fascinating but also mind-bending. The "instantly tells you something about the other" is vague. What does "instantly" really mean here, and why is it so significant?
# 4.  **How Superposition/Entanglement *Actually Help*:** I stated they "explore many solutions at once" but didn't give a concrete, simple example of *how* that parallel exploration leads to a solution more effectively than a classical brute-force approach. It's like saying "magic happens here."
#
# ---
#
# ### Step 3 - Refine Your Explanation
#
# Let's address those gaps, especially quantum probability.
#
# Imagine your regular computer, like the laptop or phone you're using. It works with "bits," which are like light switches that can be either **ON** (representing a 1) or **OFF** (representing a 0). Every piece of information, every calculation, is done by flicking millions of these tiny switches.
#
# Now, imagine a *quantum* computer. Instead of simple on/off switches, it uses "qubits." Think of a qubit not just as a light switch, but as a **spinning coin**.
#
# 1.  **Superposition (The Spinning Coin):** A regular bit is like a coin that's either Heads or Tails. A qubit, however, is like a coin that's **spinning in the air**. While it's spinning, it's not definitively Heads or Tails; it's a bit of both, or rather, it has the *potential* to be Heads and the *potential* to be Tails at the same time. This state of having multiple potentials simultaneously is called **superposition**. It's only when the coin lands (when you "measure" the qubit) that it settles down and becomes definitively Heads (0) or Tails (1).
#
# 2.  **Quantum Probability (The Biased Coin):** Now, here's the crucial part: a spinning coin can be *biased*. Imagine a magician's coin that's more likely to land on Heads than Tails. With a qubit, we can control how "biased" that spinning coin is. So, while it's in superposition (spinning), it might be 70% likely to land on Heads (0) and 30% likely to land on Tails (1). When we measure it, it *will* land on either Heads or Tails, but over many measurements, it will land on Heads roughly 70% of the time. This is **quantum probability**: the qubit isn't just a 50/50 chance; its "fuzziness" (its superposition) actually encodes the *probabilities* of it ending up in one state or another when measured. A quantum computer manipulates these probabilities to increase the chance of getting the right answer.
#
# 3.  **Entanglement (Linked Spinning Coins):** Now, imagine two of these spinning coins, but they're magically linked. If the first coin lands on Heads, the second one *instantly* flips to a specific outcome (maybe Tails), even if they're far apart. This immediate connection, where measuring one qubit instantly influences or tells you about the state of another, is called **entanglement**. It allows qubits to perform incredibly complex, simultaneous calculations together, far beyond what unentangled qubits could do. The "instant" part here means there's no time delay, no signal needs to travel between them; their states are intrinsically linked.
#
# 4.  **How Quantum Computers "Solve":** Because qubits can be in superposition (exploring many paths at once) and entangled (coordinating their exploration), a quantum computer can try out many different solutions to a problem *simultaneously* and then cleverly manipulate the **quantum probabilities** so that the *correct* solution is much more likely to show up when we finally make our measurement. Think of it like a massive maze: a regular computer tries one path at a time. A quantum computer, through superposition, explores *all* paths at once, and through entanglement, it can tell good paths from bad ones, eventually making the exit path the most probable outcome. This makes them incredibly powerful for very specific kinds of problems, like designing new materials, discovering new drugs, or cracking complex codes. They aren't just super-fast regular computers for everything; they are a completely new type of computer for specific, very hard challenges.
#
# ---
#
# ### Step 4 - Iterate and Refine (Round 1)
#
# **Identify Gaps (Round 1):**
#
# 1.  **"Manipulate the quantum probabilities":** I've explained *what* quantum probability is better, but *how* the computer manipulates them is still quite abstract for a high schooler. Saying "cleverly manipulate" or "can tell good paths from bad ones" is a bit hand-wavy.
# 2.  **The "Spinning Coin" Analogy's Limit:** While good for superposition and probability, it doesn't fully capture the multi-dimensional nature of a qubit. It's not just "Heads or Tails" bias; it can be biased towards combinations too. This is probably too complex to introduce, but it's a simplification.
# 3.  **Why "Superposition" is a big deal:** The maze analogy is okay, but I could strengthen the idea of *why* being in multiple states is so fundamentally different and powerful for computation, beyond just exploring paths.
# 4.  **"Instant" in entanglement:** While I said "no time delay," the concept of non-local influence can still feel magical and not fully grounded.
#
# **Refine Explanation (Round 1):**
#
# Imagine your regular computer, like the laptop or phone you're using. It works with "bits," which are like light switches that can be either **ON** (representing a 1) or **OFF** (representing a 0). Every piece of information, every calculation, is done by flicking millions of these tiny switches.
#
# Now, imagine a *quantum* computer. Instead of simple on/off switches, it uses "qubits." Think of a qubit not just as a light switch, but as a **compass needle**.
#
# 1.  **Superposition (The Compass Needle):** A regular bit is like a compass needle pointing strictly North (0) or South (1). A qubit, however, is like a compass needle that can **point in any direction** – North, South, East, West, or anywhere in between. While it's pointing in one of these "in-between" directions, it's not definitively North or South; it's a mix. This state of being able to hold multiple potentials simultaneously is called **superposition**. It's only when you "look" at the compass to get a North/South reading (when you "measure" the qubit) that it has to settle down and become definitively North (0) or South (1). The amazing part is that while it's spinning, it contains information about all the directions it *could* settle on.
#
# 2.  **Quantum Probability (The Magnetic Fields):** Here's how that settling works: we can apply invisible "magnetic fields" (these are like quantum operations) to our compass needle. If we apply a strong magnetic field pulling it towards North, when we finally measure, it's *more likely* to settle on North. If we pull it equally between North and South, it's 50/50. So, while the qubit is in superposition (pointing in an in-between direction), that direction itself encodes the **probabilities** of it landing on 0 or 1 when measured. A quantum computer doesn't just guess; it carefully sets up these "magnetic fields" (quantum operations) to adjust these probabilities. The goal is to make the *right answer* have the highest probability, so when we finally measure, we're very likely to get it.
#
# 3.  **Entanglement (Linked Compass Needles):** Now, imagine two of these compass needles are mysteriously linked. If one needle suddenly points North, the other one *instantly* snaps to a specific related direction (say, East), no matter how far apart they are. This immediate, deep connection, where measuring one qubit instantly tells you something about the state of another, is called **entanglement**. It's like their destinies are intertwined. The "instant" part here means their relationship exists outside the usual speed limits; it's not sending a message, but rather they are fundamentally part of the same quantum system. This allows qubits to work together in extremely powerful and complex ways, far beyond what separate qubits could do.
#
# 4.  **How Quantum Computers "Solve":** Because qubits can be in superposition (exploring many states/directions at once) and entangled (coordinating their explorations), a quantum computer can set up a problem in such a way that all the *wrong* answers' probabilities cancel each other out, while the *correct* answer's probability gets boosted. Think of it like having many paths in a maze, but the quantum computer can make the correct path "glow" much brighter than all the dead ends. When we finally look (measure), we're much more likely to find the glowing correct path. This allows them to tackle specific, incredibly complex problems much faster than traditional computers, such as designing new medications molecule by molecule, discovering materials with unheard-of properties, or breaking very strong encryption. They are a new kind of tool for new kinds of challenges.
#
# ---
#
# ### Step 4 - Iterate and Refine (Round 2)
#
# **Identify Gaps (Round 2):**
#
# 1.  **"Wrong answers' probabilities cancel each other out":** This is a key concept (quantum interference) but is still a bit abstract. How do probabilities "cancel out"? This needs a slightly more intuitive analogy.
# 2.  **"New kind of tool for new kinds of challenges":** While true, I could emphasize the *scale* of these problems more clearly, and why classical computers *fail* them.
# 3.  **The Compass Analogy for probability:** The magnetic field idea is better, but it's still hard to connect the "direction" of the compass to the specific numerical probability of 0 or 1 simply.
#
# **Refine Explanation (Round 2):**
#
# Imagine your regular computer, like the laptop or phone you're using. It works with "bits," which are like light switches that can be either **ON** (representing a 1) or **OFF** (representing a 0). Every piece of information, every calculation, is done by flicking millions of these tiny switches.
#
# Now, imagine a *quantum* computer. Instead of simple on/off switches, it uses "qubits." Think of a qubit like a **musical note**.
#
# 1.  **Superposition (The Blended Note):** A regular bit is like a single, clear note, say, Middle C (0) or High G (1). A qubit, however, can exist as a **blended chord** of notes simultaneously. It's not just Middle C or High G; it's a mix of both, perhaps with a stronger presence of Middle C. This ability to hold multiple possibilities at once is called **superposition**. It's only when you "listen closely" to find a single, distinct note (when you "measure" the qubit) that it collapses into either Middle C (0) or High G (1). While it's a chord, it contains information about all the distinct notes it *could* become.
#
# 2.  **Quantum Probability (The Volume of Each Note):** When a qubit is in superposition (like our blended chord), the "volume" or strength of each individual note within that chord tells us its **quantum probability**. If Middle C is much louder in the chord than High G, then when you finally "listen closely" and force it to pick one note, it's *much more likely* to be Middle C. A quantum computer doesn't just guess; it cleverly performs "musical adjustments" (these are quantum operations) to these chords. It manipulates the volumes of the notes within the chord. The goal is to make the "note" that represents the *correct answer* the loudest one, so when we finally listen, we're highly likely to hear it.
#
# 3.  **Entanglement (The Symphony Orchestra):** Now, imagine an entire orchestra of these musical qubit-notes, but they're incredibly linked. If the violins play a certain melody, the cellos *instantly* play a specific counter-melody in perfect harmony, no matter where they are on stage. This deep, instantaneous connection, where the state of one qubit (note) is fundamentally tied to the state of another, is called **entanglement**. It means they are part of a shared quantum "song" or system. The "instant" part highlights that their fates are intertwined without any delay; they are fundamentally connected. This allows qubits to work together in incredibly complex and coordinated ways, performing calculations that would be impossible with separate, unlinked notes.
#
# 4.  **How Quantum Computers "Solve":** Because qubits can be in superposition (playing many notes/possibilities at once) and entangled (coordinating their entire "orchestra"), a quantum computer can set up a problem like composing a complex piece of music. It can make all the "wrong answer" notes play out of tune or softly, even causing them to cancel each other out through a process similar to destructive interference in sound waves. Meanwhile, the "correct answer" note is made to resonate loudly and clearly. When we finally "listen" (measure), the overwhelming sound is the *correct solution*. This unique ability to explore vast numbers of possibilities simultaneously and then selectively amplify the right answer makes them incredibly powerful for problems like:
#     *   **Finding new materials:** Simulating how atoms and molecules interact with extreme precision, something classical computers can't handle for complex molecules.
#     *   **Drug discovery:** Designing new drug molecules by accurately modeling their quantum behavior.
#     *   **Breaking complex codes:** Cracking encryption that would take classical computers billions of years.
#     These are problems so large and intricate that even the world's most powerful classical supercomputers would take an impossibly long time to solve. Quantum computers offer a fundamentally new way to approach these challenges.

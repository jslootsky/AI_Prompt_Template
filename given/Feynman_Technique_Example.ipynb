# %%
from google import genai
import os
from typing import Dict, List
from dotenv import load_dotenv

load_dotenv("../.env")

# select your model
model = "gemini-2.5-flash"
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
# Test setup
response = client.models.generate_content(
    model= model,
    contents="Hello!"
)
print(response.text)
print("✓ Setup complete!")
# Out:
# Hello there! How can I help you today?
# ✓ Setup complete!

# %%
from prompt_template import PromptTemplate, FeynmanTemplate

# %% [markdown]
# # Example Prompt: Explain Quantum Computing (gemini 2.5 flash) NON-FEYNMAN

# %%
print("\n" + "=" * 70)
print("EXAMPLE 1: Basic Task Only")
print("=" * 70)

# Create a simple template
prompt = PromptTemplate("Explain Quantum Computing")

print("\n[Constructed Prompt]")
print(prompt.full_prompt())
# Out:
# ...
# EXAMPLE 1: Basic Task Only
# ...
#
# [Constructed Prompt]
# Explain Quantum Computing

# %%
print("\n[Response]")
response = prompt.generate(client, model)
print(response)
# Out:
# [Response]
# Quantum computing is a revolutionary new type of computing that leverages the strange and wonderful rules of quantum mechanics to solve certain problems much faster than even the most powerful classical supercomputers.
#
# To understand it, let's break down the key concepts:
#
# ### 1. Classical vs. Quantum Bits
#
# *   **Classical Bit:** The fundamental unit of information in a classical computer (like your laptop) is a **bit**. A bit can be in one of two states: **0 or 1**. It's like a light switch that is either ON or OFF.
# *   **Quantum Bit (Qubit):** The fundamental unit of information in a quantum computer is a **qubit**. Unlike a classical bit, a qubit can be **0, 1, or a superposition of both 0 and 1 simultaneously**. It's like a light switch that can be ON, OFF, or some blend of both at the same time.
#
# ### The "Magic" Ingredients of Quantum Mechanics
#
# Qubits derive their power from three core quantum phenomena:
#
# 1.  **Superposition:**
# ...

# %% [markdown]
# # Explain Quantum Computing - FEYNMAN APPROACH

# %%
prompt = FeynmanTemplate("Explain Quantum Computing")
prompt = prompt.with_feynman_learning("a high school student", num_rounds=2)
prompt = prompt.with_knowledge_gap_focus(specific_gaps=["quantum probability"])
prompt = prompt.with_chain_of_thought()

print("\n[Constructed Prompt]")
print(prompt.full_prompt())
# Out:
# [Constructed Prompt]
# Explain Quantum Computing
#
# Apply the Feynman Learning Technique:
#
# Step 1 - Simple Explanation:
# Explain this concept as if teaching a high school student. Use simple language, avoid jargon.
#
# Step 2 - Identify Gaps:
# Where did you struggle to explain it simply? What parts were unclear?
#
# Step 3 - Refine Your Explanation:
# Address the gaps you identified. Improve clarity and simplicity.
#
# Step 4 - Iterate and Refine:
# Repeat steps 2-3 for 2 refinement round(s) to deepen understanding.
#
# Pay special attention to these knowledge gaps:
#   - quantum probability
#
# For each gap, provide a clear, simple explanation that a beginner could understand.
#
# Think through this step-by-step and show your reasoning.

# %%
print("\n[Response]")
response = prompt.generate(client, model)
print(response)
# Out:
# [Response]
# Okay, let's break down Quantum Computing using the Feynman Learning Technique.
#
# ---
#
# ### Step 1 - Simple Explanation: What is Quantum Computing?
#
# Imagine you have a light switch. It's either ON or OFF. That's how a regular computer works with its basic information unit, called a **bit**. A bit is either a 0 or a 1. All the complex things your phone or laptop does are just super-fast combinations of billions of these 0s and 1s.
#
# Now, imagine a *quantum* light switch. This switch isn't just ON or OFF. It can be ON, it can be OFF, but here's the weird part: it can also be **both ON and OFF at the same time!** Not like flickering quickly, but actually existing in a state where it's a mix of both. This is the core idea behind a **quantum bit**, or **qubit**.
#
# Here’s how qubits are special and what they let quantum computers do:
#
# 1.  **Superposition (Being ON and OFF at the same time):**
# ...

# %% [markdown]
# # Analysis
#
# | Criteria | Response A | Response B |
# |--|---| -- |
# | Accuracy | Very High. Descriptions of qubits, superposition, entanglement, interference, and NISQ era are technically accurate. Mentions amplitude interference correctly. | High but slightly simplified. Correct explanations overall, but phrases like “explore many solutions at once” are a common simplification and can be misleading technically. |
# | Completeness |  |  |
# | Clarity |  |  |
# | Depth |  |  |
# | Reasoning Quality |  |  |
# | Usefulness |  |  |
